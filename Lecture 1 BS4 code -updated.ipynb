# %% [markdown]
# # Write a function to web scrape the front page of “Apartments” Housing and get a distribution of low/high end housing costs

# %%
# Import Packages
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# We talk about user agents later so run and ignore
user_agent_list = ["Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246" 
,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.111 Safari/537.36 "
,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9 "
,"Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) Gecko/20100101 Firefox/15.0.1" 
,"Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36"] 

headers = {
    'User-Agent': user_agent_list[2]}

# %% [markdown]
# ### Pull from and Explore Beautiful Soup Objects

# %%
URL = "https://www.apartments.com/los-angeles-ca/"

page = requests.get(URL, headers = headers)

# %%
page
# Out:
# <Response [200]>

# %%
print(type(page))
# Out:
# <class 'requests.models.Response'>

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-placeholder-focus="false" id="appContainer" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="email=no" name="format-detection"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <title>
#    Apartments For Rent in Los Angeles CA - 28,550 Rentals | Apartments.com
#   </title>
#   <link href="/a/05c8f3/faviconv2.ico" rel="icon"/>
#   <link href="https://www.apartments.com/los-angeles-ca/" rel="canonical">
#    <meta content="max-image-preview:large" name="robots"/>
#    <meta content="Get a great Los Angeles, CA rental on Apartments.com! Use our search filters to browse all 28,550 apartments and score your perfect place! " name="description"/>
#    <meta content="en" name="language"/>
#    <meta content="en" http-equiv="language"/>
#    <meta content="en-US" http-equiv="content-language"/>
#    <meta content="739299276152207" property="fb:app_id">
#     <meta content="Apartments.com" property="og:site_name">
#      <meta content="https://www.apartments.com/los-angeles-ca/" property="og:url"/>
#      <meta content="article" property="og:type"/>
#      <meta content=" Apartments For Rent in Los Angeles CA - 28,550 Rentals | Apartments.com" property="og:title"/>
#      <meta content="https://images1.apartments.com/i2/y-h9cAORID6dSrQyb-ubClWBR8vhzTdWhpY_0AI56S8/117/1515-colby-ave-los-angeles-ca-building-photo.jpg" property="og:image"/>
#      <meta content="4/15/2024 2:20:21 AM" property="og:updated_time"/>
#      <meta content="We simplify the process of finding a new apartment by offering renters the most comprehensive database including millions of detailed and accurate apartment listings across the United States. Our innovative technology includes the POLYGON™ search tool that allows users to define their own search areas on a map and a Plan Commute feature that helps users search for rentals in proximity to their office." property="og:description"/>
#      <meta content="summary_large_image" name="twitter:card"/>
#      <meta content="@apartmentscom" name="twitter:creator"/>
#      <meta content=" Apartments For Rent in Los Angeles CA - 28,550 Rentals | Apartments.com" name="twitter:title"/>
#      <meta content="https://images1.apartments.com/i2/y-h9cAORID6dSrQyb-ubClWBR8vhzTdWhpY_0AI56S8/117/1515-colby-ave-los-angeles-ca-building-photo.jpg" name="twitter:image"/>
#      <meta content="no-referrer-when-downgrade" name="referrer"/>
#      <link href="https://s.go-mpulse.net" rel="preconnect"/>
#      <link href="https://www.googletagmanager.com/" rel="preconnect"/>
#      <link href="https://maps.googleapis.com/" rel="preconnect"/>
#      <link href="https://images1.apartments.com" rel="preconnect"/>
#      <link as="image" fetchpriority="high" href="https://images1.apartments.com/i2/y-h9cAORID6dSrQyb-ubClWBR8vhzTdWhpY_0AI56S8/117/1515-colby-ave-los-angeles-ca-building-photo.jpg?p=1" rel="preload">
#       <link as="image" fetchpriority="high" href="https://images1.apartments.com/i2/46MYjaQ29WV0bt2w9S8aZ9_bu6p-R5Nj7hEUrZH3Fgc/117/one-museum-square-los-angeles-ca-building-photo.jpg?p=1" rel="preload">
#        <link as="style" href="/content/style.bundle.css?v=-uSpVkh796xeicVLlJ4flzL3RtJ_u790eSH6n5q3NtM" rel="preload">
#         <link as="style" href="/Modules/Search/Content/style.bundle.css?v=HNxbKPPR9BvxNLZ0LuaMoOOQ9wyeOYkccEr3oXERMWE" rel="preload">
#          <link href="https://www.apartments.com/los-angeles-ca/" hreflang="en-US" rel="alternate"/>
#          <link href="https://www.apartments.com/los-angeles-ca/" hreflang="x-default" rel="alternate"/>
#          <link href="https://www.apartments.com/es/los-angeles-ca/" hreflang="es-US" rel="alternate"/>
#          <link href="https://www.apartments.com/los-angeles-ca/2/" rel="next"/>
#          <link href="/content/style.bundle.css?v=-uSpVkh796xeicVLlJ4flzL3RtJ_u790eSH6n5q3NtM" rel="stylesheet" type="text/css"/>
#          <link href="/Modules/Search/Content/styleV2.bundle.css?v=W9e1Fjp3-cZdKJnfG3Eq52XsdlURAWHx7_ntL-DNJuk" rel="stylesheet" type="text/css"/>
#          <script type="text/javascript">
#           if (window.location.hash) {
#         var hash = window.location.hash.substr(1);
#         if (hash && hash.indexOf('/') == 0) {
#             window.location.href = window.location.protocol + '//' + window.location.host + hash;
#         }
#     }
#          </script>
#          <script>
#           !function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="3P8WP-Q4FJY-TLCKN-7L5E8-FTAFR",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"3P8WP-Q4FJY-TLCKN-7L5E8-FTAFR";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="qozv6xaxankmyzq4r3sq-f-a6e48d725-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"37","ak.cp":"736657","ak.ai":parseInt("227715",10),"ak.ol":"0","ak.cr":28,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"1b99a744","ak.r":35637,"ak.a2":n,"ak.m":"a","ak.n":"essl","ak.bpcip":"131.179.95.0","ak.cport":26251,"ak.gh":"23.1.237.53","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"reno","ak.t":"1713147621","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"580","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);
#          </script>
#          <script>
#           bazadebezolkohpepadr="1927735734"
#          </script>
#          <script defer="" src="https://www.apartments.com/akam/13/72e6e889" type="text/javascript">
#          </script>
#         </link>
#        </link>
#       </link>
#      </link>
#     </meta>
#    </meta>
#   </link>
#  </head>
#  <body class="desktop">
#   <div class="mainWrapper">
#    <header class="mainHeader mortar-wrapper" id="mainHeader">
#     <nav class="mainHeaderNavigation" id="mainHeaderNavigation">
#      <div class="menuSection" id="menuSectionLink" tabindex="0">
#       <button class="dropdownToggle primary homeBtn" id="headerMenuLink" type="button">
#        <i class="storyicon hamburgerStoryIcon" id="headerMeunIcon">
#        </i>
#        <span id="headerMenuLabel">
#         Menu
#        </span>
#       </button>
#       <div class="menuNavWrapper" id="menuNavWrapper">
#        <div id="menuNavContainer">
#         <div class="menuOpenWrapper">
#          <span class="menuHeader" id="menuHeader">
#           <i class="hamburgerBittenIcon">
#           </i>
#           <span class="menuText">
#           </span>
#          </span>
#          <ul class="menuNavigation" id="menuNavigation" tabindex="0">
#           <li tabindex="0">
#            <a class="expandable" data-requirelogin="false" href="#">
#             Renter Tools
#             <i class="storyicon right2StoryIcon">
#             </i>
#            </a>
#            <ul class="submenu tools" tabindex="0">
#             <li tabindex="0">
#              <a href="https://www.apartments.com/my-account/#FavoriteListings">
#               Favorites
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/my-account/#SavedSearches">
#               Saved Searches
#              </a>
#             </li>
#             <li id="rentCalculator" tabindex="0">
#              <a href="https://www.apartments.com/rent-affordability-calculator/">
#               Rental Calculator
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li id="manageRentalsContainer" tabindex="0">
#            <a href="https://www.apartments.com/rental-manager" id="menuNavLnkManageRental">
#             Manage Rentals
#            </a>
#           </li>
#           <li id="menuNavItemContainer1" tabindex="0">
#            <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/">
#             Apartments For Rent
#             <i class="storyicon right2StoryIcon">
#             </i>
#             <i class="storyicon addStoryIcon expand-icon">
#             </i>
#             <i class="storyicon minusStoryIcon expand-icon">
#             </i>
#            </a>
#            <ul class="submenu properties">
#             <li tabindex="0">
#              <a href="https://www.apartments.com/beverly-hills-ca/">
#               Beverly Hills Apartments For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/culver-city-ca/">
#               Culver City Apartments For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/hollywood-ca/">
#               Hollywood Apartments For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/los-angeles-ca/">
#               Los Angeles Apartments For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/north-hollywood-ca/">
#               North Hollywood Apartments For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/santa-monica-ca/">
#               Santa Monica Apartments For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/studio-city-ca/">
#               Studio City Apartments For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/van-nuys-ca/">
#               Van Nuys Apartments For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/venice-ca/">
#               Venice Apartments For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/west-hollywood-ca/">
#               West Hollywood Apartments For Rent
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li id="menuNavItemContainer2" tabindex="0">
#            <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/houses/los-angeles-ca/">
#             Houses For Rent
#             <i class="storyicon right2StoryIcon">
#             </i>
#             <i class="storyicon addStoryIcon expand-icon">
#             </i>
#             <i class="storyicon minusStoryIcon expand-icon">
#             </i>
#            </a>
#            <ul class="submenu properties">
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/barrington-ca/">
#               Barrington Houses For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/beverly-hills-ca/">
#               Beverly Hills Houses For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/hollywood-ca/">
#               Hollywood Houses For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/irvine-ca/">
#               Irvine Houses For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/laguna-beach-ca/">
#               Laguna Beach Houses For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/los-angeles-ca/">
#               Los Angeles Houses For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/malibu-ca/">
#               Malibu Houses For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/newport-beach-ca/">
#               Newport Beach Houses For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/north-hollywood-ca/">
#               North Hollywood Houses For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/studio-city-ca/">
#               Studio City Houses For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/van-nuys-ca/">
#               Van Nuys Houses For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/houses/west-hollywood-ca/">
#               West Hollywood Houses For Rent
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li id="menuNavItemContainer3" tabindex="0">
#            <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/condos/los-angeles-ca/">
#             Condos For Rent
#             <i class="storyicon right2StoryIcon">
#             </i>
#             <i class="storyicon addStoryIcon expand-icon">
#             </i>
#             <i class="storyicon minusStoryIcon expand-icon">
#             </i>
#            </a>
#            <ul class="submenu properties">
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/barrington-ca/">
#               Barrington Condos For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/beverly-hills-ca/">
#               Beverly Hills Condos For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/bradley-international-ca/">
#               Bradley International Condos For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/del-valle-finance-ca/">
#               Del Valle Finance Condos For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/hollywood-ca/">
#               Hollywood Condos For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/irvine-ca/">
#               Irvine Condos For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/los-angeles-ca/">
#               Los Angeles Condos For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/newport-beach-ca/">
#               Newport Beach Condos For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/santa-monica-ca/">
#               Santa Monica Condos For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/venice-ca/">
#               Venice Condos For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/west-hollywood-ca/">
#               West Hollywood Condos For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/condos/westchester-ca/">
#               Westchester Condos For Rent
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li id="menuNavItemContainer4" tabindex="0">
#            <a class="expandable" data-requirelogin="false" href="https://www.apartments.com/townhomes/los-angeles-ca/">
#             Townhomes For Rent
#             <i class="storyicon right2StoryIcon">
#             </i>
#             <i class="storyicon addStoryIcon expand-icon">
#             </i>
#             <i class="storyicon minusStoryIcon expand-icon">
#             </i>
#            </a>
#            <ul class="submenu properties">
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/burbank-ca/">
#               Burbank Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/dana-point-ca/">
#               Dana Point Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/gardena-ca/">
#               Gardena Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/irvine-ca/">
#               Irvine Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/laguna-beach-ca/">
#               Laguna Beach Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/long-beach-ca/">
#               Long Beach Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/los-angeles-ca/">
#               Los Angeles Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/newport-beach-ca/">
#               Newport Beach Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/north-hollywood-ca/">
#               North Hollywood Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/redondo-beach-ca/">
#               Redondo Beach Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/studio-city-ca/">
#               Studio City Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/torrance-ca/">
#               Torrance Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/valley-village-ca/">
#               Valley Village Townhomes For Rent
#              </a>
#             </li>
#             <li tabindex="0">
#              <a href="https://www.apartments.com/townhomes/west-hollywood-ca/">
#               West Hollywood Townhomes For Rent
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li tabindex="0">
#            <a data-requirelogin="false" href="https://www.apartments.com/rent-market-trends/los-angeles-ca/" id="menuNavRentTrends" target="RentTrends_6sesybt">
#             Los Angeles Average Rent
#            </a>
#           </li>
#           <li tabindex="0">
#            <a data-requirelogin="false" href="https://www.apartments.com/about/help" id="menuNavHelpCenter" target="_blank">
#             Help Center
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="header-switch-language-wrapper mortar-wrapper">
#       <a class="headerSwitchLanguage header-is-selected-language" data-culture="en-US" data-url="https://www.apartments.com/los-angeles-ca/" href="https://www.apartments.com/los-angeles-ca/" title="English">
#        <i class="storyicon externalWebsiteStoryIcon">
#        </i>
#        <span>
#         English
#        </span>
#       </a>
#       <div aria-describedby="modal-description" aria-labelledby="modal-header" aria-modal="true" class="language-pop modal" role="dialog">
#        <p class="header3" id="modal-header">
#         Language
#        </p>
#        <div class="modal-actions">
#         <a class="btn btn-sm btn-pill culture header-pill-selected" data-culture="en-US" data-url="https://www.apartments.com/los-angeles-ca/" href="https://www.apartments.com/los-angeles-ca/" title="English">
#          <span>
#           English
#          </span>
#         </a>
#         <a class="btn btn-sm btn-pill culture" data-culture="es-US" data-url="https://www.apartments.com/es/los-angeles-ca/" href="https://www.apartments.com/es/los-angeles-ca/" title="Español">
#          <span>
#           Español
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="logoSpacer">
#      </div>
#      <div class="logo">
#       <a aria-label="Apartments.com logo visited to home link" href="https://www.apartments.com/" id="homeLink">
#        <img alt="Apartments.com Logo" src="/a/4d9af0/content/images/apartments-for-rent-logo.png"/>
#       </a>
#      </div>
#      <div class="notifications-wrapper mortar-wrapper">
#       <div class="notifications-favorites" id="notificationsFavorites" title="Favorites">
#        <i aria-label="Favorites" class="storyicon favoriteOutlineStoryIcon" role="button" tabindex="0">
#        </i>
#        <span class="notifications-count" id="notificationsFavoritesCount">
#        </span>
#        <span class="label">
#         Favorites
#        </span>
#        <i class="storyicon closeStoryIcon selector-clear">
#        </i>
#       </div>
#       <div class="notifications-new-listings-alerts" id="tooltipItemNewListings" listings="" title="New">
#        <i aria-label="New Listings" class="storyicon lightningBoltStoryIcon" role="button" tabindex="0">
#        </i>
#        <span class="notifications-count" id="newListingCount">
#        </span>
#        <span class="label">
#         New
#        </span>
#        <i class="storyicon closeStoryIcon selector-clear">
#        </i>
#       </div>
#       <div class="notifications-alerts" id="tooltipItemNotifications" title="Alerts">
#        <div class="bell-container">
#         <i aria-label="Alerts" class="storyicon alertStoryIcon" role="button" tabindex="0">
#         </i>
#         <div class="notifications-circle" id="notificationsCircle" style="display: none;">
#         </div>
#        </div>
#        <span class="label">
#         Alerts
#        </span>
#       </div>
#      </div>
#      <div class="loginPrevNextWrapper">
#       <div class="loginSection" id="headerLoginSection">
#        <a class="headerSignIn" href="javascript:void(0);" id="headerManageRental" title="Manage Rentals">
#         Manage Rentals
#        </a>
#        <a class="js-headerSignUp headerSignUp" href="javascript:void(0);" title="Sign Up">
#         Sign Up
#        </a>
#        <span>
#         /
#        </span>
#        <a class="js-headerSignin headerSignIn" href="javascript:void(0);" title="Sign In">
#         Sign In
#        </a>
#       </div>
#       <a aria-label="Add a Property link" href="javascript:void(0);" id="headerAddProperty" title="Add a Property">
#        <span>
#         Add a Property
#        </span>
#       </a>
#      </div>
#     </nav>
#    </header>
#    <script type="application/ld+json">
#     {"@type":"SearchResultsPage","contentLocation":{"containedIn":{"@type":"State","name":"CA"},"@type":"City","name":"Los Angeles"},"breadcrumb":[{"itemListElement":[{"@type":"ListItem","position":1,"item":{"name":"California","@id":"https://www.apartments.com/ca/"}},{"@type":"ListItem","position":2,"item":{"name":"Los Angeles County","@id":"https://www.apartments.com/los-angeles-county-ca/"}},{"@type":"ListItem","position":3,"item":{"name":"Los Angeles","@id":"https://www.apartments.com/los-angeles-ca/"}},{"@type":"ListItem","position":4,"item":{"name":"Los Angeles CA Apartments ","@id":"https://www.apartments.com/los-angeles-ca/"}}],"@context":"http://schema.org","@type":"BreadcrumbList"}],"speakable":{"@type":"SpeakableSpecification","cssSelector":["#marketingBlurb > p"],"xpath":["/html/head/meta[@name='description']/@content"]},"about":[{"url":"https://www.apartments.com/1515-colby-ave-los-angeles-ca/13pvg74/","image":"https://images1.apartments.com/i2/y-h9cAORID6dSrQyb-ubClWBR8vhzTdWhpY_0AI56S8/117/1515-colby-ave-los-angeles-ca-building-photo.jpg?p=1","Address":{"@type":"PostalAddress","streetAddress":"1515 Colby Ave","addressLocality":"Los Angeles","addressRegion":"CA","postalCode":"90025","addressCountry":"US"},"telephone":"+1-424-351-9154","@type":"ApartmentComplex","name":"1515 Colby Ave","@id":"https://www.apartments.com/1515-colby-ave-los-angeles-ca/13pvg74/"},{"url":"https://www.apartments.com/one-museum-square-los-angeles-ca/0d1dm62/","image":"https://images1.apartments.com/i2/46MYjaQ29WV0bt2w9S8aZ9_bu6p-R5Nj7hEUrZH3Fgc/117/one-museum-square-los-angeles-ca-building-photo.jpg?p=1","Address":{"@type":"PostalAddress","streetAddress":"640 S Curson Ave","addressLocality":"Los Angeles","addressRegion":"CA","postalCode":"90036","addressCountry":"US"},"telephone":"+1-323-815-7566","@type":"ApartmentComplex","name":"One Museum Square","@id":"https://www.apartments.com/one-museum-square-los-angeles-ca/0d1dm62/"},{"url":"https://www.apartments.com/the-gemma-los-angeles-ca/ssl2gk7/","image":"https://images1.apartments.com/i2/HB0Jfjh89jdhlLYEjy9H0gMKUg_0Q-uCZn3YVKisWyw/117/the-gemma-los-angeles-ca-building-photo.jpg?p=1","Address":{"@type":"PostalAddress","streetAddress":"3540 Wilshire Blvd","addressLocality":"Los Angeles","addressRegion":"CA","postalCode":"90010","addressCountry":"US"},"telephone":"+1-213-652-7543","@type":"ApartmentComplex","name":"The Gemma","@id":"https://www.apartments.com/the-gemma-los-angeles-ca/ssl2gk7/"},{"url":"https://www.apartments.com/ferrante-los-angeles-ca/l3tcd8d/","image":"https://images1.apartments.com/i2/qnamYgFjuTMFqZyrOvAoroYmDU14WAVsIVMitKpSAns/117/ferrante-los-angeles-ca-building-photo.jpg?p=1","Address":{"@type":"PostalAddress","streetAddress":"300 N Beaudry Ave","addressLocality":"Los Angeles","addressRegion":"CA","postalCode":"90012","addressCountry":"US"},"telephone":"+1-213-799-5635","@type":"ApartmentComplex","name":"Ferrante","@id":"https://www.apartments.com/ferrante-los-angeles-ca/l3tcd8d/"},{"url":"https://www.apartments.com/rise-koreatown-los-angeles-ca/qzle2gx/","image":"https://images1.apartments.com/i2/xao6PFJRLAkjdkEG9YsuWMbo1j6nZD4J_qiixRJ4MaE/117/rise-koreatown-los-angeles-ca-building-photo.jpg?p=1","Address":{"@type":"PostalAddress","streetAddress":"750 S Oxford Ave","addressLocality":"Los Angeles","addressRegion":"CA","postalCode":"90005","addressCountry":"US"},"telephone":"+1-323-990-4302","@type":"ApartmentComplex","name":"Rise Koreatown","@id":"https://www.apartments.com/rise-koreatown-los-angeles-ca/qzle2gx/"},{"url":"https://www.apartments.com/arq-los-angeles-ca/h9t7ky3/","image":"https://images1.apartments.com/i2/fusReRkk5FuqbwgZ-hfgmxgQIk338CKhhe4rziM89M0/117/arq-los-angeles-ca-building-photo.jpg?p=1","Address":{"@type":"PostalAddress","streetAddress":"3311 S La Cienega Blvd","addressLocality":"Los Angeles","addressRegion":"CA","postalCode":"90016","addressCountry":"US"},"telephone":"+1-213-514-8681","@type":"ApartmentComplex","name":"ARQ","@id":"https://www.ap ...
#    </script>
#    <script type="application/ld+json">
#     [{"@context":"https://schema.org","@type":"Event","name":"3D Tour - 1515 Colby Ave","description":"1515 Colby Ave Apartments for rent to view a 3D tour.","url":"https://www.apartments.com/1515-colby-ave-los-angeles-ca/13pvg74/#3dtours","image":"https://images1.apartments.com/i2/y-h9cAORID6dSrQyb-ubClWBR8vhzTdWhpY_0AI56S8/117/1515-colby-ave-los-angeles-ca-building-photo.jpg?p=1","startDate":"2024-04-14","endDate":"2024-04-14","eventStatus":"https://schema.org/EventScheduled","eventAttendanceMode":"https://schema.org/OnlineEventAttendanceMode","location":[{"url":"https://www.apartments.com/1515-colby-ave-los-angeles-ca/13pvg74/#3dtours","@type":"VirtualLocation"},{"address":{"@type":"PostalAddress","streetAddress":"1515 Colby Ave","addressLocality":"Los Angeles","addressRegion":"CA","postalCode":"90025","addressCountry":"US"},"@type":"Place","name":"1515 Colby Ave Apartments"}]},{"@context":"https://schema.org","@type":"Event","name":"3D Tour - One Museum Square","description":"One Museum Square Apartments for rent to view a 3D tour.","url":"https://www.apartments.com/one-museum-square-los-angeles-ca/0d1dm62/#3dtours","image":"https://images1.apartments.com/i2/46MYjaQ29WV0bt2w9S8aZ9_bu6p-R5Nj7hEUrZH3Fgc/117/one-museum-square-los-angeles-ca-building-photo.jpg?p=1","startDate":"2024-04-14","endDate":"2024-04-14","eventStatus":"https://schema.org/EventScheduled","eventAttendanceMode":"https://schema.org/OnlineEventAttendanceMode","location":[{"url":"https://www.apartments.com/one-museum-square-los-angeles-ca/0d1dm62/#3dtours","@type":"VirtualLocation"},{"address":{"@type":"PostalAddress","streetAddress":"640 S Curson Ave","addressLocality":"Los Angeles","addressRegion":"CA","postalCode":"90036","addressCountry":"US"},"@type":"Place","name":"One Museum Square Apartments"}]},{"@context":"https://schema.org","@type":"Event","name":"3D Tour - The Gemma","description":"The Gemma Apartments for rent to view a 3D tour.","url":"https://www.apartments.com/the-gemma-los-angeles-ca/ssl2gk7/#3dtours","image":"https://images1.apartments.com/i2/HB0Jfjh89jdhlLYEjy9H0gMKUg_0Q-uCZn3YVKisWyw/117/the-gemma-los-angeles-ca-building-photo.jpg?p=1","startDate":"2024-04-14","endDate":"2024-04-14","eventStatus":"https://schema.org/EventScheduled","eventAttendanceMode":"https://schema.org/OnlineEventAttendanceMode","location":[{"url":"https://www.apartments.com/the-gemma-los-angeles-ca/ssl2gk7/#3dtours","@type":"VirtualLocation"},{"address":{"@type":"PostalAddress","streetAddress":"3540 Wilshire Blvd","addressLocality":"Los Angeles","addressRegion":"CA","postalCode":"90010","addressCountry":"US"},"@type":"Place","name":"The Gemma Apartments"}]},{"@context":"https://schema.org","@type":"Event","name":"3D Tour - ARQ","description":"ARQ Apartments for rent to view a 3D tour.","url":"https://www.apartments.com/arq-los-angeles-ca/h9t7ky3/#3dtours","image":"https://images1.apartments.com/i2/fusReRkk5FuqbwgZ-hfgmxgQIk338CKhhe4rziM89M0/117/arq-los-angeles-ca-building-photo.jpg?p=1","startDate":"2024-04-14","endDate":"2024-04-14","eventStatus":"https://schema.org/EventScheduled","eventAttendanceMode":"https://schema.org/OnlineEventAttendanceMode","location":[{"url":"https://www.apartments.com/arq-los-angeles-ca/h9t7ky3/#3dtours","@type":"VirtualLocation"},{"address":{"@type":"PostalAddress","streetAddress":"3311 S La Cienega Blvd","addressLocality":"Los Angeles","addressRegion":"CA","postalCode":"90016","addressCountry":"US"},"@type":"Place","name":"ARQ Apartments"}]},{"@context":"https://schema.org","@type":"Event","name":"3D Tour - Residences at West Edge","description":"Residences at West Edge Apartments for rent to view a 3D tour.","url":"https://www.apartments.com/residences-at-west-edge-los-angeles-ca/4j9smvh/#3dtours","image":"https://images1.apartments.com/i2/_mKCGfXb6svWfZ7KLXDwa_ebyzbEbjZz5MtRRmU0nTI/117/residences-at-west-edge-los-angeles-ca-building-photo.jpg?p=1","startDate":"2024-04-14","endDate":"2024-04-14","eventStatus":"https://schema.org/Event ...
#    </script>
#    <main>
#     <section class="searchApp" id="searchApp">
#      <header class="searchBar" id="searchBar">
#       <!--[if lte IE 9]>
# <div class="searchBarWrapper no-flex clearfix">
# <![endif]-->
#       <!--[if (gt IE 9)|!(IE)]><!-->
#       <div class="search-bar-wrapper">
#        <!--<![endif]-->
#        <div class="mortar-wrapper backToSearch">
#         <a class="btn btn-md btn-primary" data-bind="visible: isBackToSearchVisible(), click: backToSearchClick" href="javascript:void(0);" id="backToSearch" style="display: none;" title="Back to Search">
#          <i class="storyicon backStoryIcon">
#          </i>
#          <span>
#           Back to Search
#          </span>
#         </a>
#        </div>
#        <span class="lookup mortar-wrapper" data-bind="visible: isTypeaheadVisible()">
#         <i class="searchIcon storyicon searchStoryIcon">
#         </i>
#         <label class="screenReaderOnly" for="searchBarLookup">
#          Search input
#         </label>
#         <input autocomplete="off" autocorrect="false" class="searchBarLookup" data-bind="css: { savedSearchVisible: isSavedSearchVisible() }" id="searchBarLookup" placeholder="Location or Point of Interest" type="text"/>
#        </span>
#        <span data-bind="with: rentRange, visible: isRentRangeVisible()" id="rentMinMaxRangeControl">
#         <div class="rentRangeSelector dropDownContainer" data-bind="css: { 'active-filter': isOpen()}, event: { keydown: keyDown }">
#          <a class="btn btn-default rentselector" data-bind="click: selectorClicked, clickBubble: true, css: { active: isOpen(), 'has-value': minRentHasValue() === true || maxRentHasValue() === true || optionsHasValue() === true}" id="rentRangeLink" role="button" tabindex="0" title="Price">
#           <span class="search-filter-label" data-bind="text: selectedDisplayValue()">
#            Price
#           </span>
#           <span class="mortar-wrapper search-filter-icon">
#            <i class="storyicon down2StoryIcon">
#            </i>
#            <i class="storyicon up2StoryIcon">
#            </i>
#            <i class="storyicon closeStoryIcon selector-clear" data-bind="visible: minRentHasValue() || maxRentHasValue() || optionsHasValue(), click: rentRangeClear" style="display: none;">
#            </i>
#           </span>
#          </a>
#          <div class="dropdownContent mortar-wrapper">
#           <div class="min-max-ranges">
#            <fieldset class="text md">
#             <label class="screenReaderOnly" for="min-input">
#              minimum Rent Input
#             </label>
#             <input autocomplete="off" class="minRentInput" data-bind="css: { active: isMinRentActive() }, event: { focus: minRentFocus, blur: rentInputBlur }, value: minRent, clickBubble: false" id="min-input" maxlength="6" pattern="\$?(\d|,)*" placeholder="Min Rent" type="tel">
#             </input>
#            </fieldset>
#            <i class="storyicon minusStoryIcon min-max-ranges-icon">
#            </i>
#            <fieldset class="text md">
#             <label class="screenReaderOnly" for="max-input">
#              maximum Rent Input
#             </label>
#             <input autocomplete="off" class="maxRentInput" data-bind="css: { active: !isMinRentActive() }, event: { focus: maxRentFocus, blur: rentInputBlur }, value: maxRent, clickBubble: false" id="max-input" maxlength="6" pattern="\$?(\d|,)*" placeholder="Max Rent" type="tel"/>
#            </fieldset>
#           </div>
#           <ul class="minRentOptions js-minRentOptions" data-bind="css: { active: isMinRentActive() }, click: minRentOptionsClicked, clickBubble: false">
#            <li class="active" data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="">
#             No Min
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="2000">
#             $2,000
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="2500">
#             $2,500
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="3000">
#             $3,000
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="4000">
#             $4,000
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="5000">
#             $5,000
#            </li>
#            <li data-bind="css: { active: isMinRangeOptionActive($element) }, scrollIntoView: isMinRangeOptionActive($element) &amp;&amp; isOpen(), visible: isMinRangeOptionVisible($element)" data-value="9000">
#             $9,000
#            </li>
#           </ul>
#           <ul class="maxRentOptions js-maxRentOptions" data-bind="css: { active: !isMinRentActive() }, visible: !minRentHasValue(), click: maxRentOptionsClicked, clickBubble: false" id="maxRentOptions">
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="2500">
#             $2,500
#            </li>
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="3000">
#             $3,000
#            </li>
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="3500">
#             $3,500
#            </li>
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="4000">
#             $4,000
#            </li>
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="5500">
#             $5,500
#            </li>
#            <li data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="9000">
#             $9,000
#            </li>
#            <li class="active" data-bind="css: { active: isMaxRangeOptionActive($element) }, scrollIntoView: isMaxRangeOptionActive($element) &amp;&amp; !isMinRentActive()" data-value="">
#             No Max
#            </li>
#           </ul>
#           <ul class="maxRentOptions js-customMaxRentOptions" data-bind="foreach: maxRentValues, css: { active: !isMinRentActive() }, visible: minRentHasValue(), click: maxRentOptionsClicked, clickBubble: false">
#            <li data-bind="text: text, attr: { 'data-value': value },  css: { active: $parent.isMaxRangeOptionActive($element) }, scrollIntoView: $parent.isMaxRangeOptionActive($element) &amp;&amp; !$parent.isMinRentActive()">
#            </li>
#           </ul>
#           <div class="no-broker-fee-section mortar-wrapper">
#            <fieldset class="checkbox">
#             <input class="checkbox-default" data-value="32" id="noBrokerFee" type="checkbox"/>
#             <label for="noBrokerFee">
#              <span>
#               Only show listings with no broker’s fee
#              </span>
#             </label>
#            </fieldset>
#           </div>
#           <div class="action-footer mortar-wrapper">
#            <button class="clear-btn btn btn-sm btn-text" data-bind="click: rentRangeClear">
#             <span>
#              Clear
#             </span>
#            </button>
#            <button class="done-btn btn btn-sm btn-text" data-bind="click: selectorClicked">
#             Done
#            </button>
#           </div>
#          </div>
#         </div>
#        </span>
#        <span data-bind="with: bedsRange, visible: isBedRangeVisible()" id="bedsMinMaxRangeControl">
#         <div class="bedsRangeSelector dropDownContainer" data-bind="css: { 'active-filter': isBedsOpen()}">
#          <a class="btn btn-default bedselector" data-bind="click: selectorClicked, clickBubble: true, css: { active: isBedsOpen(), 'has-value': minBedsHasValue() || maxBedsHasValue() || minBathsHasValue() }" id="bedRangeLink" role="button" tabindex="0" title="Beds" type="button">
#           <span class="search-filter-label" data-bind="text: selectedDisplayValue()">
#            Beds/Baths
#           </span>
#           <span class="mortar-wrapper search-filter-icon">
#            <i class="storyicon down2StoryIcon">
#            </i>
#            <i class="storyicon up2StoryIcon">
#            </i>
#            <i class="storyicon closeStoryIcon selector-clear" data-bind="visible: minBedsHasValue() || maxBedsHasValue() || minBathsHasValue() , click: bedsClear" style="display: none;">
#            </i>
#           </span>
#          </a>
#          <div class="dropdownContent mortar-wrapper">
#           <div class="content-container">
#            <div class="bed-filter-container">
#             <h2 class="title">
#              Beds
#             </h2>
#             <p>
#              Select two tiles for min/max range
#             </p>
#             <div class="ranges">
#              <button class="bed-filter-button" data-bind="css: { highlighted: isBedsOptionActive($element) }, click: bedsOptionsClicked, clickBubble: false" data-value="0">
#               Any
#              </button>
#              <button class="bed-filter-button" data-bind="css: { highlighted: isBedsOptionActive($element) }, click: bedsOptionsClicked, clickBubble: false" data-value="-1">
#               Studio+
#              </button>
#              <button class="bed-filter-button" data-bind="css: { highlighted: isBedsOptionActive($element) }, click: bedsOptionsClicked, clickBubble: false" data-value="1">
#               1+
#              </button>
#              <button class="bed-filter-button" data-bind="css: { highlighted: isBedsOptionActive($element) }, click: bedsOptionsClicked, clickBubble: false" data-value="2">
#               2+
#              </button>
#              <button class="bed-filter-button" data-bind="css: { highlighted: isBedsOptionActive($element) }, click: bedsOptionsClicked, clickBubble: false" data-value="3">
#               3+
#              </button>
#              <button class="bed-filter-button" data-bind="css: { highlighted: isBedsOptionActive($element) }, click: bedsOptionsClicked, clickBubble: false" data-value="4">
#               4+
#              </button>
#             </div>
#            </div>
#            <div class="bath-filter-container">
#             <h2 class="title">
#              Baths
#             </h2>
#             <div class="ranges">
#              <button class="bath-filter-button" data-bind="css: { highlighted: isBathOptionActive($element) }, click: bathsOptionsClicked, clickBubble: false" data-value="0">
#               Any
#              </button>
#              <button class="bath-filter-button" data-bind="css: { highlighted: isBathOptionActive($element) }, click: bathsOptionsClicked, clickBubble: false" data-value="1">
#               1+
#              </button>
#              <button class="bath-filter-button" data-bind="css: { highlighted: isBathOptionActive($element) }, click: bathsOptionsClicked, clickBubble: false" data-value="2">
#               2+
#              </button>
#              <button class="bath-filter-button" data-bind="css: { highlighted: isBathOptionActive($element) }, click: bathsOptionsClicked, clickBubble: false" data-value="3">
#               3+
#              </button>
#             </div>
#            </div>
#            <div class="action-footer mortar-wrapper">
#             <button class="clear-btn btn btn-sm btn-text" data-bind="click: bedsClear">
#              <span>
#               Clear
#              </span>
#             </button>
#             <button class="done-btn btn btn-sm btn-text" data-bind="click: selectorClicked">
#              Done
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#        </span>
#        <span data-bind="with: searchType, visible: isTypeButtonVisible()" id="SHTypeControl">
#         <div id="type-selection-wrapper">
#          <a class="btn btn-default" data-bind="click: searchTypeClicked, clickBubble: true, css: {'active': isSearchTypeMenuVisible, 'has-value': hasTypeSelected()}" id="typeSelect" role="button" tabindex="0">
#           <span class="label search-filter-label">
#            Home Type
#           </span>
#           <span class="search-filter-label" data-bind="text: selectedDisplayValue()">
#           </span>
#           <span class="mortar-wrapper search-filter-icon">
#            <i class="storyicon down2StoryIcon">
#            </i>
#            <i class="storyicon up2StoryIcon">
#            </i>
#            <i class="storyicon closeStoryIcon selector-clear" data-bind="visible: isTypeSelected(), click: typeClear" style="display: none;">
#            </i>
#           </span>
#          </a>
#          <div class="drop-down-container mortar-wrapper home-type-filter" data-bind="visible: isSearchTypeMenuVisible(), css: {'active': isSearchTypeMenuVisible}">
#           <div class="wrapper">
#            <button data-bind="disable: hasNoTypeFacets($element), css:{}" data-value="1" id="PropertyType-1" value="1">
#             <a href="javascript:void(0);" title="">
#             </a>
#             <i class="storyicon propApartmentStoryIcon">
#             </i>
#             <span>
#              Apartments
#             </span>
#            </button>
#            <button data-bind="disable: hasNoTypeFacets($element), css:{}" data-value="2" id="PropertyType-2" value="2">
#             <a href="https://www.apartments.com/houses/los-angeles-ca/" title="">
#             </a>
#             <i class="storyicon propHouseStoryIcon">
#             </i>
#             <span>
#              Houses
#             </span>
#            </button>
#            <button data-bind="disable: hasNoTypeFacets($element), css:{}" data-value="4" id="PropertyType-4" value="4">
# ...
#          <button class="closeIcon" data-dismiss="modal" type="button">
#           <i class="storyicon closeStoryIcon">
#           </i>
#          </button>
#          <p class="applyNowModalTitle">
#           Ready to Apply?
#          </p>
#          <p>
#           Good News! This rental is accepting applications through Apartments.com. Act now and your $
#           <span id="renterApplicationFee">
#           </span>
#           purchase will include 9 additional FREE application submissions to participating properties.
#          </p>
#          <div class="modalActions">
#           <button class="primary" id="continueToAppButton" type="button">
#            Sign Up to Apply
#           </button>
#           <p>
#            Or
#            <button class="link" id="continueSignInButton" type="button">
#             sign in
#            </button>
#            if you already have an account
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="searchFavoritesModals" id="searchFavoritesModals">
#       </div>
#       <div id="myPlacesErrorModalWrapper">
#       </div>
#       <div id="searchErrorModalWrapper">
#       </div>
#       <div id="locateMeModalWrapper">
#       </div>
#       <div id="geoNoContentNotification">
#       </div>
#       <div class="videoPlayerWrapper fade modal" id="modalVirtualTourContainer">
#        <div class="videoPlayerWrapper" id="virtualTourVideoPlayerWrapper">
#         <div class="viewerContent" id="virtualTourViewerContent">
#          <div class="videoPlayer active" id="virtualTourVideoPlayer">
#           <span class="mortar-wrapper">
#            <button class="storyicon closeStoryIcon close closeIcon" data-dismiss="modal" type="button">
#            </button>
#           </span>
#           <div class="videoPlayerContent" id="virtualTourPlayerContent">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="videoPlayerWrapper fade modal" id="modalVideoGalleryContainer">
#        <div class="videoPlayerWrapper" id="videoGalleryVideoPlayerWrapper">
#         <div class="viewerContent" id="videoGalleryViewerContent">
#          <div class="videoPlayer active" id="videoGalleryVideoPlayer">
#           <span class="mortar-wrapper">
#            <button class="storyicon closeStoryIcon close closeIcon" data-dismiss="modal" type="button">
#            </button>
#           </span>
#           <div class="videoPlayerContent" id="videoGalleryPlayerContent">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <section id="placardApplyNow">
#        <section class="ConduitFrameContainer is-modal" id="ApplyNowFrameContainer">
#        </section>
#        <section class="ConduitFrameContainer is-modal" id="EcomRenterCheckoutFrameContainer">
#        </section>
#        <section class="ConduitFrameContainer is-modal" id="RequestToApplyFrameContainer">
#        </section>
#        <section class="app-transition-spinner">
#         <div class="mortar-wrapper content">
#          <i class="storyillustration apartmentsLogoStoryIllustration loading-spinner">
#          </i>
#          <p class="loading-text">
#          </p>
#         </div>
#        </section>
#       </section>
#      </input>
#     </section>
#     <div class="modalBackdrop fade in" id="allFiltersBackdrop" style="display: none">
#     </div>
#    </main>
#   </div>
#   <div class="modals">
#   </div>
#   <!-- OneTrust Cookies Consent Notice start -->
#   <script charset="UTF-8" data-document-language="true" data-domain-script="46a3efe3-1529-4775-8478-83fa14924969" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function OptanonWrapper() {}
#   </script>
#   <!-- OneTrust Cookies Consent Notice end  -->
#   <script type="text/javascript">
#    window.cohortVariant = -1;
#         window.ga_Unique_ClientId = '';
#   </script>
#   <script type="text/javascript">
#    var LogManagerConfig = {
#             Source: 'Apartments',
#             PostUrl: '/services/log/',
#             MachineKey: 'vj80BA/LXVs7qdYS/KJK44I/ma36o+0grTVKq7NE/WA='
#         };
#         window._moduleLoadTimeout = 30;
# 				window._fs_org = 'N8KG7';
#   </script>
#   <script src="/scripts/scripts.en-us.bundle.js?v=sMBFOTEX-1tZz47nO9T2pc-MD1C3CsS7R3LXE1_h90A">
#   </script>
#   <script>
#    require(['configuration'], function(configuration) {
#         configuration.configure({
#             debugLevel: 0,
#             mode: 'desktop',
#             operatingSystemType: 'macos',
#
#             culture: 'en-US',
#             alternateCultureLinks: [{"u":"https://www.apartments.com/los-angeles-ca/","n":"English","c":"en-US","o":"https://www.apartments.com/los-angeles-ca/"},{"u":"https://www.apartments.com/es/los-angeles-ca/","n":"Español","c":"es-US","o":"https://www.apartments.com/es/los-angeles-ca/"}],
#
# 			securedAppDomain: 'https://www.apartments.com',
# 			appDomain: 'https://www.apartments.com',
# 			activityLoggingApiRoot: 'https://www.apartments.com/',
# 		    enableBoundedSearch: true,
#
#             cookieDomain: 'www.apartments.com',
#             videoDomain: 'https://vapi.apartments.com',
# 			myPlacesEntries: 7,
# 			FacebookAppId: '739299276152207',
# 			GoogleClientId: '584308931288-s77uuon9vudl4n0vumhu14sggrit46b4.apps.googleusercontent.com',
# 			GoogleApiKey: 'AIzaSyC8m7Iic_Ua4j0_JxFtwJMyz-Iqjtv08Ws',
# 			GoogleReCaptchaSiteKey: '6LfAZf0UAAAAAHMLAEHq-4jSUUk9Z3HKFgkvjFl-',
# 			comscoreClientId: '18075227',
# 			googleAnalyticsKey: 'UA-1746553-2',
#             googleTagManagerKey: 'GTM-5CC6LZ6',
#             enableGoogleTagManager: true,
#             //googleOptimizeKey: 'GTM-TS2M8NB',
#             enableGoogleOptimize: true,
#             googleDoubleClickFloodlightKey: 'DC-6337982',
# 			maxFavorites: 10,
# 			eventMaxParallel: 4,
# 			placardDefferredImage: true,
# 			showListingFreshnessOption: true,
# 			ajaxTimeout: 60000,
# 			virtualTourUrl: 'https://my.matterport.com/show/?m={0}',
# 			maxSearchHistory: 6,
# 			maxProfileViewHistory: 20,
# 			authCookieExpires: 1,
#             ratingsAndReviewsToUUrl: 'https://www.apartments.com/about/ratings-and-reviews-terms-of-use',
#             apartmentsToSUrl: 'https://www.apartments.com/about/terms-of-service',
# 			enableSmsAddEdit: false,
# 			maxFileUploadSize: 75,
# 			unitCountThreshold: 2,
#             googleMapsPath: 'https://maps.googleapis.com/maps/api/js?key=AIzaSyB2BQJGkjJywjEcxptZzuUWCTkfxlLlSWE&libraries=geometry,places&channel=apartments&v=quarterly',
# 			enableSavedSearchesLoginPopupFeature: false,
#             enableExploreNeighborhoods: false,
# 			adTaggingEnabled: true,
# 			activityLoggingEnabled: true,
# 			enableGeoIPFallbackCall: true,
# 			enableInfoCardsV2: true,
#             enableVectorGeoShape: true,
#             enableVectorRemoveOutline: false,
#             mtExpireDays: 30,
#             isContactedRentalEnabled: false,
#             enableCaptcha: true,
#             enableMfa: true,
#             enableFreeRentSign: true,
#             freeRentSignRequestTimeLimit: 30,
#             enablePropertyManagementTools: false,
#             olcr: 'https://leasing.apartments.com/routes/leasing/renter/client',
#             geographyShapeServerUrl: 'https://shapes.apartments.com',
#             psr: 'https://payments.apartments.com',
#             rpr: '/renter-payments/v1/iframe/tenant-payments',
#             pacfu: '/payments/accounts/frame',
#             aft: 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJuYmYiOjE3MTMxNDc2MjEsImV4cCI6MTcxMzIzNDAyMSwiaWF0IjoxNzEzMTQ3NjIxLCJpc3MiOiJodHRwczovL3d3dy5hcGFydG1lbnRzLmNvbSIsImF1ZCI6Imh0dHBzOi8vd3d3LmFwYXJ0bWVudHMuY29tIn0.uV1s6pQZhrW8s-itq_D6_XMGRkiQpEqamklu2NZGCZw',
#             antiWebCrawlerToken: '',
#
#
#
#             enableOl: "true",
#             erp: true,
#             pa: true,
#             isEc: false,
#             ercr: 'https://ecom.apartments.com/routes/ecom/renter/client',
#             elcr: 'https://ecom.apartments.com/routes/ecom/landlord/client',
#             cear: 'https://ecom.apartments.com/routes/ecom',
#             colar: 'https://leasing.apartments.com/routes/leasing',
#
#             caOrigin: 'https://auth.apartments.com',
#             caCI: 'apartments',
#
#             disableCheckSession: true,
#             isClientLoggingOn: false,
#             mktDomain: 'https://www.apartments.com/routes/mkt',
#             maximumNumberOfVideosToUploadPerListing: 6,
#             enableVideoUpload: true,
#             maxVideoSize: 1000,
#             disableRequestToApplyForUnitRange: 50,
#             mktLandlordDomain: 'https://www.apartments.com/routes/mkt/landlord',
#             mktLandlordClientDomain: 'https://www.apartments.com/mkt/client/landlord',
#             mktRenterClientDomain: 'https://www.apartments.com/mkt/client/renter',
#             enableMessaging: true,
#             enableScheduleToursV2: true,
#             isModifiedLeadFormEnabled: true,
#             pusherAppKey: '4363500863af37511506',
#             pusherCluster: 'us3',
#             enableLDPShapesEndpoint: false,
#             enableLDPReviewsMKTEndpoint: true,
#             siftBeaconKey: '507f7b9fba',
#             environment: 'PROD LAX',
#             enableSiftTracking: true,
#             frenchCanadaEnabled: true,
#             creaUrl: 'https://analytics.crea.ca/LogEvents.svc/LogEvents',
#             creaDestinationId: '52069'
# 		});
#     });
#   </script>
#   <script type="text/javascript">
#    require(['Application'],
# 			function(app) {
#                 app.setCultureUrl('https://www.apartments.com/es/los-angeles-ca/');
#                 app.setCultureCanonicalUrl('https://www.apartments.com/es/los-angeles-ca/');
# 			});
#   </script>
#   <script src="/Modules/Search/Scripts/search.bundle.js?v=Mlu9f3G4WdI6sqvu7PkRXckqukB4_jX_hcxpG8_pxKU">
#   </script>
#   <script type="text/javascript">
#    require(['SearchStartup', 'FullstoryManager'],
#             function (startup, FullstoryManager) {
#                 window['_fs_selected_traffic'] = 'true';
# 						    if (window['_fs_selected_traffic'] && window['_fs_selected_traffic'] === 'true') {
# 								    FullstoryManager.init('N8KG7');
# 						    }
#
#
#             startup.init({
#                 resultState: {"ResultKey":null,"MetaState":{"Title":null,"PagePreviousUrl":null,"PageNextUrl":null,"FirstImageUrl":null,"SecondImageUrl":null,"PreConnectUrl":null,"IsShowPreConnectUrl":null,"Follow":null,"LocationMeta":{"PinImage":null,"GeographyType":2},"PreloadFirstImageUrl":null,"PreloadSecondImageUrl":null},"UrlState":{"Url":"https://www.apartments.com/los-angeles-ca/","CanonicalUrl":"https://www.apartments.com/los-angeles-ca/","NewModeSearchUrl":"https://www.apartments.com/los-angeles-ca/new/","NeighborhoodUrl":"https://www.apartments.com/los-angeles-ca/#guide","cus":[{"u":"https://www.apartments.com/los-angeles-ca/","n":"English","c":"en-US","o":"https://www.apartments.com/los-angeles-ca/"},{"u":"https://www.apartments.com/es/los-angeles-ca/","n":"Español","c":"es-US","o":"https://www.apartments.com/es/los-angeles-ca/"}]},"PinsState":{"cl":"vten4bg|5|null|34.3203|-118.49272|0~c3hehqf|4|null|34.28224|-118.60824|0~qcbwysx|4|null|34.28135|-118.47023|0~qzj0hyy|5|null|34.27939|-118.5727|0~3ldc0yg|5|null|34.27906|-118.57745|0~cenr3td|5|null|34.27788|-118.57263|0~brjg99c|4|null|34.27694|-118.40528|0~d7s2gjh|4|null|34.25668|-118.59319|0~w57x3tk|5|null|34.25601|-118.52826|0~0gy1rf0|5|null|34.24895|-118.52251|0~xc96bcp|5|null|34.24726|-118.5226|0~vy06jtg|5|null|34.24406|-118.52227|0~ne6zfjq|5|null|34.24134|-118.56088|0~gmy3l7y|5|null|34.23872|-118.57059|0~4fvfg5k|4|null|34.23744|-118.55901|0~h5wvd83|5|null|34.23613|-118.53418|0~v20b8wd|4|null|34.231|-118.534|0~44wvmph|4|null|34.22887|-118.556|0~bp5h2w8|5|null|34.22568|-118.4525|0~zb30vly|4|null|34.22414|-118.53714|0~ptg2rps|4|null|34.22226|-118.50724|0~gfcp93w|4|null|34.22019|-118.59921|0~nsywq1n|5|null|34.21998|-118.59983|0~q4ckk5w|5|null|34.21952|-118.44937|0~fqy56ev|4|null|34.21243|-118.60535|0~rn1s2k1|4|null|34.20459|-118.43051|0~2ztkx6b|5|null|34.20208|-118.56181|0~ehgljyn|5|null|34.20077|-118.52557|0~j6mfdj7|4|null|34.20074|-118.46926|0~7hqqhcw|4|null|34.2006|-118.54842|0~n0jdpyp|5|null|34.20007|-118.48413|0~zkgf4zx|5|null|34.19991|-118.45057|0~2rv8hcc|4|null|34.19977|-118.40145|0~yxcq7yr|5|null|34.19712|-118.39696|0~0cznkw1|5|null|34.19709|-118.4656|0~s7v9xe7|4|null|34.19468|-118.44774|0~38l7eqg|5|null|34.19438|-118.59873|0~j2fmv27|5|null|34.19345|-118.58999|0~jh5lfn6|4|null|34.1928|-118.32667|0~97yb2t6|5|null|34.19239|-118.5911|0~g9zjb3x|5|null|34.19119|-118.33984|0~ry0vfc1|4|null|34.19109|-118.5365|0~mx3h5dl|5|null|34.19087|-118.59434|0~zmr347w|4|null|34.19086|-118.44831|0~xgxpy3p|5|null|34.19084|-118.59219|0~8wlvy93|4|null|34.19053|-118.43153|0~tc615y8|5|null|34.19031|-118.59204|0~x64hrdn|5|null|34.18921|-118.46554|0~6n5jy9r|4|null|34.18884|-118.46553|0~4dyzerj|5|null|34.18582|-118.58925|0~pwm6jhr|5|null|34.18503|-118.60893|0~b4wdg4b|5|null|34.18492|-118.60636|0~m6n342h|5|null|34.18442|-118.59591|0~6vyjl4r|4|null|34.1833|-118.60089|0~0ce5jh2|5|null|34.18269|-118.45647|0~sk94r75|4|null|34.18261|-118.39427|0~2j9l30b|5|null|34.1826|-118.60837|0~w4j01yh|5|null|34.18244|-118.59671|0~zw6s1zy|5|null|34.18064|-118.61151|0~lckyxpf|5|null|34.18039|-118.59378|0~wcm3vmk|5|null|34.17977|-118.30628|0~p2w26nr|4|null|34.17424|-118.46584|0~h40pyy2|5|null|34.17322|-118.60636|0~nykc4em|4|null|34.17262|-118.60761|0~e41v1nn|4|null|34.1724|-118.4504|0~z8pthkw|5|null|34.17191|-118.50869|0~3znzchf|4|null|34.17162|-118.525|0~zrf6lxx|5|null|34.17148|-118.37441|0~2bq4kkb|4|null|34.17109|-118.37284|0~nq0d3km|4|null|34.17059|-118.52494|0~6lqs4fs|4|null|34.17015|-118.52076|0~r7528n1|5|null|34.16985|-118.60778|0~xekh7xm|5|null|34.16966|-118.37839|0~1xfljv4|4|null|34.16943|-118.53968|0~n6bmd8q|5|null|34.16937|-118.60758|0~grd2efx|5|null|34.16926|-118.37782|0~r3f1hr0|5|null|34.16895|-118.38282|0~748qwfy|5|null|34.16828|-118.36372|0~83n5pv2|5|null|34.16826|-118.37945|0~rb784y1|4|null|34.1682|-118.40471|0~rj6vpy1|4|null|34.16803|-118.28467|0~k87wk69|4|null|34.16761|-118.40066|0~9k6p5r4|4|null|34.16734|-118.46804|0~1evzbv7|4|null|34.16665|-118.57904|0~30t3g3g|5|null|34.16649|-118.5817|0~l2c ...
#                 sortOptions: [{"Item1":0,"Item2":"Sort","Item3":"Default"},{"Item1":2,"Item2":"Rent","Item3":"Rent (low to high)"},{"Item1":1,"Item2":"Rent","Item3":"Rent (high to low)"},{"Item1":4,"Item2":"Video","Item3":"Video"},{"Item1":6,"Item2":"3D Tour","Item3":"3D Tour"},{"Item1":8,"Item2":"Last Updated","Item3":"Last Updated"}],
#                 redirectState: null,
#                 myApplicationsUrl: 'https://www.apartments.com/my-account/#MyApplications'
#             });
#         });
#   </script>
#   <script>
#    (function (h, o, u, n, d) {
#                 h = h[d] = h[d] || { q: [], onReady: function (c) { h.q.push(c) } }
#                 d = o.createElement(u); d.async = 1; d.src = n
#                 n = o.getElementsByTagName(u)[0]; n.parentNode.insertBefore(d, n)
#             })(window, document, 'script', 'https://www.datadoghq-browser-agent.com/us1/v5/datadog-rum.js', 'DD_RUM')
#             window.DD_RUM.onReady(function () {
#                 window.DD_RUM.init({
#                     clientToken: 'pub08d5433a94f84641b397f65bf3e07a97',
#                     applicationId: '3d075e4f-7938-48bd-9df9-3ae53b0ff168',
#                     site: 'datadoghq.com',
#                     service: 'apartmentsweb-prd-search-page',
#                     env: 'prd',
#                     // Specify a version number to identify the deployed version of your application in Datadog
#                     // version: '1.0.0',
#                     sessionSampleRate: 1,
#                     sessionReplaySampleRate: 0,
#                     trackUserInteractions: true,
#                     trackResources: true,
#                     trackLongTasks: true,
#                     defaultPrivacyLevel: 'mask-user-input',
#                 });
#             })
#   </script>
#   <noscript>
#    <img src="https://www.apartments.com/akam/13/pixel_72e6e889?a=dD1mMjc1ZTNkYjY0NGM4MDEzZGNhZWMzMTcyODM4MzVhYTVjN2Y0NTBhJmpzPW9mZg==" style="visibility: hidden; position: absolute; left: -999px; top: -999px;"/>
#   </noscript>
#  </body>
# </html>

# %%
soup.find("p")
# Out:
# <p class="header3" id="modal-header">Language</p>

# %%
soup.findAll("p")
# Out:
# [<p class="header3" id="modal-header">Language</p>,
#  <p> Select two tiles for min/max range</p>,
#  <p>
#                          Select two tiles for min/max range
#                      </p>,
#  <p class="error" data-bind="visible: !sqFeetIsValid(), text: squareFeetErrorMessage"></p>,
#  <p class="keywordDirections"></p>,
#  <p>
#          Set a destination, transportation method, and your ideal commute time to see results.
#      </p>,
#  <p class="errorMessage" data-bind="visible: toShowTAError">*Please enter your address or point of interest</p>,
#  <p>
#          Select your school and find the perfect place nearby or on-campus.
#      </p>,
#  <p class="loading-text"></p>,
#  <p class="property-pricing">$1,200 - 6,235</p>,
#  <p class="property-beds">3-4 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>Specials</span>
#  </p>,
#  <p class="property-amenities">
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Stainless Steel Appliances</span>
#  <span>Controlled Access</span>
#  <span>Gated</span>
#  <span>Elevator</span>
#  <span>Private Bathroom</span>
#  </p>,
#  <p class="property-pricing">$2,973 - 7,975</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Clubhouse</span>
#  </p>,
#  <p class="property-pricing">$2,250 - 3,750</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>Specials</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Walk-In Closets</span>
#  </p>,
#  <p class="property-pricing">$1,973 - 5,070</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>2 Months Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Maintenance on site</span>
#  <span>Business Center</span>
#  <span>Controlled Access</span>
#  </p>,
#  <p class="property-pricing">$2,360 - 4,465</p>,
#  <p class="property-beds">Studio - 1 Bed</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Kitchen</span>
#  <span>Clubhouse</span>
#  </p>,
#  <p class="property-pricing">$3,695 - 10,019</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>Specials</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Clubhouse</span>
#  <span>Maintenance on site</span>
#  <span>Stainless Steel Appliances</span>
#  <span>Business Center</span>
#  </p>,
#  <p class="property-pricing">$2,725 - 7,512</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>2 Months Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Clubhouse</span>
#  <span>Balcony</span>
#  </p>,
#  <p class="property-pricing">$2,195 - 3,573</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>2 Months Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Clubhouse</span>
#  <span>Elevator</span>
#  </p>,
#  <p class="property-pricing">$3,175 - 5,000</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Balcony</span>
#  <span>Maintenance on site</span>
#  <span>Disposal</span>
#  <span>Microwave</span>
#  </p>,
#  <p class="property-pricing">$2,499 - 8,284</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Kitchen</span>
#  <span>Tub / Shower</span>
#  <span>Grill</span>
#  <span>Courtyard</span>
#  </p>,
#  <p class="property-pricing">$1,650 - 2,220</p>,
#  <p class="property-beds">1 Bed</p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Stainless Steel Appliances</span>
#  <span>Ceiling Fans</span>
#  <span>Controlled Access</span>
#  <span>Hardwood Floors</span>
#  <span>Elevator</span>
#  <span>Laundry Facilities</span>
#  <span>Smoke Free</span>
#  </p>,
#  <p class="property-pricing">$2,650 - 3,895</p>,
#  <p class="property-beds">1-2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Package Service</span>
#  <span>Controlled Access</span>
#  <span>EV Charging</span>
#  <span>Rooftop Deck</span>
#  </p>,
#  <p class="property-pricing">$2,034 - 6,279</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Clubhouse</span>
#  <span>Range</span>
#  <span>CableReady</span>
#  </p>,
#  <p class="property-pricing">$2,215 - 3,930</p>,
#  <p class="property-beds">1-2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Heat</span>
#  <span>EV Charging</span>
#  </p>,
#  <p class="property-pricing">$2,141 - 5,016</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>Specials</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Clubhouse</span>
#  <span>Stainless Steel Appliances</span>
#  <span>Hardwood Floors</span>
#  <span>Online Services</span>
#  </p>,
#  <p class="property-pricing">$2,475 - 7,215</p>,
#  <p class="property-beds">Studio - 4 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Clubhouse</span>
#  <span>Balcony</span>
#  </p>,
#  <p class="property-pricing">$2,595 - 7,050</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>2 Months Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Ceiling Fans</span>
#  <span>Controlled Access</span>
#  <span>Rooftop Deck</span>
#  </p>,
#  <p class="property-pricing">$2,299 - 4,252</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Kitchen</span>
#  <span>Walk-In Closets</span>
#  <span>High-Speed Internet</span>
#  <span>Gated</span>
#  </p>,
#  <p class="property-pricing">$1,375 - 4,995</p>,
#  <p class="property-beds">Studio - 4 Beds</p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Walk-In Closets</span>
#  </p>,
#  <p class="property-pricing">$2,550 - 8,150</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-amenities">
#  <span>Clubhouse</span>
#  <span>Business Center</span>
#  <span>Package Service</span>
#  <span>Controlled Access</span>
#  <span>Hardwood Floors</span>
#  <span>EV Charging</span>
#  <span>Rooftop Deck</span>
#  </p>,
#  <p class="property-pricing">$2,444 - 5,470</p>,
#  <p class="property-beds">1-3 Beds</p>,
#  <p class="property-amenities">
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Maintenance on site</span>
#  <span>Package Service</span>
#  <span>Basketball Court</span>
#  </p>,
#  <p class="property-pricing">$2,950 - 9,431</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-amenities">
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>High-Speed Internet</span>
#  <span>Package Service</span>
#  <span>Concierge</span>
#  <span>Doorman</span>
#  </p>,
#  <p class="property-pricing">$2,053 - 3,391</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Clubhouse</span>
#  <span>Balcony</span>
#  </p>,
#  <p class="property-pricing">$2,568 - 5,830</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>2 Months Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Walk-In Closets</span>
#  <span>Clubhouse</span>
#  <span>Maintenance on site</span>
#  <span>Stainless Steel Appliances</span>
#  </p>,
#  <p class="property-pricing">$2,585 - 12,610</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>2 Months Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Balcony</span>
#  <span>Range</span>
#  </p>,
#  <p class="property-pricing">$2,295 - 9,773</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>2 Months Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Refrigerator</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Range</span>
#  <span>Microwave</span>
#  <span>Heat</span>
#  </p>,
#  <p class="property-pricing">$2,498 - 3,998</p>,
#  <p class="property-beds">1-2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>Specials</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Kitchen</span>
#  <span>Balcony</span>
#  <span>Range</span>
#  <span>Oven</span>
#  <span>Controlled Access</span>
#  <span>Laundry Facilities</span>
#  <span>Fireplace</span>
#  </p>,
#  <p class="property-pricing">$1,540 - 2,405</p>,
#  <p class="property-beds">Studio - 1 Bed</p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Stainless Steel Appliances</span>
#  <span>Controlled Access</span>
#  <span>Granite Countertops</span>
#  <span>Hardwood Floors</span>
#  <span>Laundry Facilities</span>
#  </p>,
#  <p class="property-pricing">$1,575 - 2,879</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Clubhouse</span>
#  <span>Business Center</span>
#  <span>Controlled Access</span>
#  <span>Laundry Facilities</span>
#  <span>EV Charging</span>
#  </p>,
#  <p class="property-pricing">$2,398 - 2,798</p>,
#  <p class="property-beds">2 Beds</p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  </p>,
#  <p class="property-pricing">$2,582 - 4,338</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Walk-In Closets</span>
#  <span>Clubhouse</span>
#  </p>,
#  <p class="property-pricing">$2,613 - 8,441</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Clubhouse</span>
#  <span>Balcony</span>
#  </p>,
#  <p class="property-pricing">$4,880 - 12,750</p>,
#  <p class="property-beds">1-2 Beds</p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Balcony</span>
#  <span>Package Service</span>
#  <span>EV Charging</span>
#  </p>,
#  <p class="property-pricing">$2,563 - 27,799</p>,
#  <p class="property-beds">1-3 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Microwave</span>
#  <span>Concierge</span>
#  </p>,
#  <p class="property-pricing">$10,000 - 25,000</p>,
#  <p class="property-beds">1-4 Beds</p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Walk-In Closets</span>
#  </p>,
#  <p class="property-pricing">$2,000 - 3,200</p>,
#  <p class="property-beds">Studio - 2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>1 Month Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Walk-In Closets</span>
#  <span>Clubhouse</span>
#  </p>,
#  <p class="property-pricing">$2,703 - 6,571</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>2 Months Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>Dishwasher</span>
#  <span>Refrigerator</span>
#  <span>Kitchen</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Walk-In Closets</span>
#  </p>,
#  <p class="property-pricing">$2,950 - 5,100</p>,
#  <p class="property-beds">Studio - 3 Beds</p>,
#  <p class="property-amenities">
#  <span>Pool</span>
#  <span>Package Service</span>
#  <span>Concierge</span>
#  <span>Office</span>
#  <span>EV Charging</span>
#  <span>Doorman</span>
#  </p>,
#  <p class="property-pricing">$2,498 - 3,998</p>,
#  <p class="property-beds">1-2 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>Specials</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Kitchen</span>
#  <span>Range</span>
#  <span>High-Speed Internet</span>
#  <span>Tub / Shower</span>
#  <span>Elevator</span>
#  <span>Smoke Free</span>
#  </p>,
#  <p class="property-pricing">$2,497 - 6,300</p>,
#  <p class="property-beds">1-3 Beds</p>,
#  <p class="property-specials">
#  <i class="storyicon saleStoryIcon"></i>
#  <span>2 Months Free</span>
#  </p>,
#  <p class="property-amenities">
#  <span>Dog &amp; Cat Friendly</span>
#  <span>Fitness Center</span>
#  <span>Pool</span>
#  <span>In Unit Washer &amp; Dryer</span>
#  <span>Walk-In Closets</span>
#  <span>Balcony</span>
#  <span>Concierge</span>
#  </p>,
#  <p class="searchResults">
#                  Showing 40 of 700 Results -
#                  <span class="pageRange">Page 1 of 18</span>
#  </p>,
#  <p>There are numerous nicknames for Los Angeles, just as there are various vibes within this sprawling city. Between rugged mountains and sandy shorelines, a laid-back surf culture and a high-powered commercial district, and food trucks and some of the world’s top-rated restaurants, Los Angeles features diversity in every aspect possible. Somehow, all the pieces of this city fit together seamlessly, making Los Angeles the unique destination we know and love. From Rodeo Drive and Beverly Hills to Hollywood and <a href="https://www.apartments.com/chinatown-los-angeles-ca/">Chinatown</a>, there is the perfect neighborhood for everyone in Los Angeles.
#
#  From celebrity sightings to unbeatable shopping destinations, Los Angeles is hard to beat. Enjoy a hike in the Santa Monica Mountains, <a href="https://www.apartments.com/parks-and-recreation/ca/los-angeles/griffith-park/">Griffith Park</a>, or Topanga State Park, enjoy the famous entertainment at Universal Studios Hollywood, see the stars along the legendary Hollywood Walk of Fame, or stop into the Los Angeles County Museum of Art. Your options are endless for entertainment, dining, and shopping in Los Angeles. And don’t forget about the easy access to international travel through the expansive Los Angeles International Airport. </p>,
#  <p>Though Los Angeles is famous for its film industry, it’s also well-known for its amazing beaches like <a href="https://www.apartments.com/venice-beach-los-angeles-ca/">Venice Beach</a>, Santa Monica Beach, El Matador Beach, Manhattan Beach, and Hermosa Beach. After a day of surfing and swimming, catch a sporting event or a live show at LA Live, housing the Microsoft Theatre, the STAPLES Center, the Grammy Museum, and a variety of restaurants and nightclubs. Outside of entertainment, Los Angeles houses numerous prestigious colleges and universities, from the <a href="https://www.apartments.com/off-campus-housing/ca/los-angeles/university-of-california-los-angeles/">University of California, Los Angeles</a> to the <a href="https://www.apartments.com/off-campus-housing/ca/los-angeles/university-of-southern-california-health-sciences-campus/">University of Southern California</a>.</p>,
#  <p>
#  <a class="localGuideLink" data-islocalguidev2="True" href="https://www.apartments.com/local-guide/los-angeles-ca/" id="localGuideLink" tabindex="0" target="Guide_6sesybt">
#  					Learn More about Los Angeles, CA
#  				</a>
#  </p>,
#  <p>The<a href="https://www.apartments.com/rent-market-trends/los-angeles-ca/" target="RentTrends_6sesybt"> average rent in Los Angeles</a> is $2,094. When you rent an apartment in Los Angeles, you can expect to pay as little as $1,654 or as much as $4,137, depending on the location and the size of the apartment.</p>,
#  <p>The average rent for a <a href="https://www.apartments.com/los-angeles-ca/studios/">studio</a> apartment in Los Angeles, CA is $1,654 per month.</p>,
#  <p>The average rent for a <a href="https://www.apartments.com/los-angeles-ca/1-bedrooms/">one bedroom</a> apartment in Los Angeles, CA is $2,100 per month.</p>,
#  <p>The average rent for a <a href="https://www.apartments.com/los-angeles-ca/2-bedrooms/">two bedroom</a> apartment in Los Angeles, CA is $2,893 per month.</p>,
#  <p>The average rent for a <a href="https://www.apartments.com/los-angeles-ca/3-bedrooms/">three bedroom</a> apartment in Los Angeles, CA is $4,137 per month.</p>,
#  <p>Transit options in Los Angeles vary, but overall, it has a transit score of 63.</p>,
#  <p>In Los Angeles, you’ll find top-ranking elementary schools like <a href="https://www.apartments.com/schools/ca/valley-view-elementary/zs6rpmw/">Valley View Elementary</a>, <a href="https://www.apartments.com/schools/ca/third-street-elementary/fqfbtdv/">Third Street Elementary</a>, and <a href="https://www.apartments.com/schools/ca/vena-avenue-elementary/97llfm4/">Vena Avenue Elementary</a>.</p>,
#  <p>Los Angeles is home to some top-ranking middle schools, including <a href="https://www.apartments.com/schools/ca/girls-academic-leadership-academy-dr-michelle-king-school-for-sci-tech-eng-and-math/181qb65/">Girls Academic Leadership Academy, Dr. Michelle King School For Sci, Tech, Eng And Math</a>, <a href="https://www.apartments.com/schools/ca/science-academy-stem-magnet/c00xt1e/">Science Academy STEM Magnet</a>, and <a href="https://www.apartments.com/schools/ca/sherman-oaks-center-for-enriched-studies/7gf2hsz/">Sherman Oaks Center For Enriched Studies</a>.</p>,
#  <p>Moving is tough for high school students! Look for Los Angeles apartments near top-ranking high schools like <a href="https://www.apartments.com/schools/ca/harbor-teacher-preparation-academy/p2hnhxt/">Harbor Teacher Preparation Academy</a>, <a href="https://www.apartments.com/schools/ca/girls-academic-leadership-academy-dr-michelle-king-school-for-sci-tech-eng-and-math/181qb65/">Girls Academic Leadership Academy, Dr. Michelle King School For Sci, Tech, Eng And Math</a>, and <a href="https://www.apartments.com/schools/ca/middle-college-high/ltlbrrd/">Middle College High</a>.</p>,
#  <p>If you’re a student moving to an apartment in Los Angeles, you’ll have access to <a href="https://www.apartments.com/off-campus-housing/ca/santa-monica/santa-monica-college-santa-monica-bundy-campus/">Santa Monica Coll., Bundy</a>, <a href="https://www.apartments.com/off-campus-housing/ca/culver-city/west-los-angeles-college/">West Los Angeles College</a>, and <a href="https://www.apartments.com/off-campus-housing/ca/santa-monica/santa-monica-college-airport-arts-campus/">Santa Monica Coll., Airport</a>.</p>,
#  <p class="mortar-wrapper ehoSearchLabel">
#  <a href="https://www.apartments.com/about/equal-opportunity-in-housing-statement" target="_blank" title="Equal Housing Opportunity">
#  <i class="storyicon equalHousingStoryIcon ehoIcon"></i>
#  <span>Equal Housing Opportunity</span>
#  </a>
#  </p>,
#  <p>You must save a search in order to receive alerts.</p>,
#  <p>Save your current search and get the latest updates on new listings matching your search criteria!</p>,
#  <p class="preferenceLabel" id="preferenceLabel">I would like to...</p>,
#  <p>Submitting Request</p>,
#  <p class="successModalTitle" id="successModalHeader">Thank You</p>,
#  <p class="message" id="successModalMsg">Thank you! Your email has been sent.</p>,
#  <p class="applyNowModalTitle">Ready to Apply?</p>,
#  <p>Good News! This rental is accepting applications through Apartments.com. Act now and your $<span id="renterApplicationFee"></span> purchase will include 9 additional FREE application submissions to participating properties.</p>,
#  <p>
#  										Or <button class="link" id="continueSignInButton" type="button">sign in</button> if you already have an account
#  								</p>,
#  <p class="loading-text"></p>]

# %%
price_elements = soup.findAll("p", class_ = "property-pricing")

# %% [markdown]
# ### Find the pricing inside of the website

# %%
clean_p = [i.text for i in price_elements]

# %%
clean_p[0]
# Out:
# '$1,200 - 6,235'

# %%
# low price 
float(clean_p[0].split("-")[0].replace("$", "").replace(",", ""))
# Out:
# 1200.0

# %%
# high price 
float(clean_p[0].split("-")[1].replace("$", "").replace(",", ""))
# Out:
# 6235.0

# %% [markdown]
# ### Clean the Prices

# %%
lows = []
highs = []

for i in clean_p:
    try:
        lows.append(float(i.split("-")[0].replace("$", "").replace(",", "")))
    except:
         lows.append(np.nan)
            
    try:
        highs.append(float(i.split("-")[1].replace("$", "").replace(",", "")))
    except:
         highs.append(np.nan)

# %% [markdown]
# ### Make a function out or it

# %%
def get_prices():
    user_agent_list = ["Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246" 
    ,"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.111 Safari/537.36 "
    ,"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9 "
    ,"Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:15.0) Gecko/20100101 Firefox/15.0.1" 
    ,"Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36"] 

    headers = {
        'User-Agent': user_agent_list[2]}
    
    URL = "https://www.apartments.com/los-angeles-ca/"

    page = requests.get(URL, headers = headers)
    
    soup = BeautifulSoup(page.content, "html.parser")
    
    price_elements = soup.findAll("p", class_ = "property-pricing")
    
    clean_p = [i.text for i in price_elements]
    
    lows = []
    highs = []

    for i in clean_p:
        try:
            lows.append(float(i.split("-")[0].replace("$", "").replace(",", "")))
        except:
             lows.append(np.nan)

        try:
            highs.append(float(i.split("-")[1].replace("$", "").replace(",", "")))
        except:
             highs.append(np.nan)
                
    return(lows, highs)

# %%
lows, highs = get_prices()

# %%
highs
# Out:
# [4995.0,
#  8150.0,
#  5470.0,
#  9431.0,
#  3391.0,
#  5830.0,
#  12610.0,
#  9773.0,
#  3998.0,
#  2405.0,
#  2879.0,
#  2798.0,
#  4338.0,
#  8441.0,
#  12750.0,
#  27799.0,
#  25000.0,
#  3200.0,
#  6571.0,
#  5100.0,
#  3998.0,
#  6300.0,
#  4804.0,
#  5632.0,
#  4398.0,
#  3966.0,
#  20500.0,
#  3395.0,
#  12352.0,
#  9106.0,
#  10000.0,
#  8210.0,
#  nan,
#  6414.0,
#  8709.0,
#  6235.0,
#  7975.0,
#  3750.0,
#  5070.0,
#  4465.0]
